# %%
# Name:     Tariq Nawaz 
# Address:  Bannu KPK
# Mobile :  03205519719

# %%
# Q1

# %%
print('Twinkle twinklw little star','\n', '\t' ,
      'How I wonder what you are' , '\n', '\t \t',
      'Up above the world so high','\n','\t \t',
      'Like a diomond in the sky','\n',
      'Twinkle twinklw little star','\n', '\t' , 
      'How I wonder what you are')
# Out:
# Twinkle twinklw little star
#  	 How I wonder what you are
#  	 	 Up above the world so high
#  	 	 Like a diomond in the sky
#  Twinkle twinklw little star
#  	 How I wonder what you are

# %%
# Q2

# %%
# !python -V
# Out:
# Python 3.7.6

# %%
# OR

# %%
from platform import python_version

# %%
print(python_version())
# Out:
# 3.7.6

# %%
# Q3

# %%
from datetime import datetime

# %%
dt=datetime.now()

# %%
print(dt)
# Out:
# 2021-12-31 19:24:22.538747

# %%
# New Formate
dt_string=dt.strftime('%d/%m/%Y %H:%M:%S')
print(dt_string)
# Out:
# 31/12/2021 19:24:22

# %%
# Q4

# %%
pi=22/7
r=float(input('Put value of Radius'))
area=pi * r * r
print(area)
# Out:
# Put value of Radius4
# 50.285714285714285

# %%
f_name=input('Enter your First Name: ')
l_name=input('Enter your last Name: ')
print(f_name[::-1],' ',l_name[::-1])
# Out:
# Enter your First Name: sd
# Enter your last Name: hg
# ds   gh

# %%
f_name=input('Enter your First Name: ')
l_name=input('Enter your last Name: ')
print(l_name,'',f_name)
# Out:
# Enter your First Name: fgh
# Enter your last Name: hgf
# hgf  fgh

# %%
# Q 5

# %%
v1=int(input('Put your first value'))
v2=int(input('Put your second value'))
v3= v1 + v2
print('Addition of v1 and v2 is :',v3)
# Out:
# Put your first value77
# Put your second value66
# Addition of v1 and v2 is : 143

# %%
# Thanks To Sir Muhammad Ali Mughal
